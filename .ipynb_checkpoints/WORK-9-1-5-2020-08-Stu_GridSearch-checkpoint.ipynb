# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('Final_Dataset.csv')
df.head(10)
# Out:
#                        Region  Year  Number of deaths  \
# 0         East Asia & Pacific  2000             34000
# 1       Europe & Central Asia  2000              3400
# 2   Latin America & Caribbean  2000             12000
# 3  Middle East & North Africa  2000              8700
# 4               North America  2000               510
# 5                  South Asia  2000            147000
# 6          Sub-Saharan Africa  2000            236000
# 7         East Asia & Pacific  2001             32000
# 8       Europe & Central Asia  2001              3300
# 9   Latin America & Caribbean  2001             11000
#
#    Lifetime risk of maternal death (%)  \
# 0                                 0.21
# 1                                 0.05
# 2                                 0.29
# 3                                 0.38
# 4                                 0.02
# 5                                 1.45
# 6                                 4.72
# 7                                 0.20
# 8                                 0.05
# 9                                 0.27
#
#    Maternal mortality ratio (deaths per 100,000 live births)  \
# 0                                                113
# 1                                                 33
# 2                                                 99
# 3                                                113
# 4                                                 12
# 5                                                388
# 6                                                846
# 7                                                110
# 8                                                 32
# 9                                                 95
#
#    Domestic private health expenditure (% of current health expenditure)  \
# 0                                              29.52
# 1                                              24.49
# 2                                              56.91
# 3                                              44.46
# 4                                              54.50
# 5                                              73.61
# 6                                              60.33
# 7                                              29.90
# 8                                              24.36
# 9                                              56.79
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                               4.34
# 1                                               5.88
# 2                                               2.53
# 3                                               2.48
# 4                                               5.56
# 5                                               0.87
# 6                                               1.72
# 7                                               4.36
# 8                                               6.04
# 9                                               2.60
#
#    GDP per capita (international-$)
# 0                           7178.89
# 1                          22220.70
# 2                          11458.67
# 3                          13554.73
# 4                          45146.13
# 5                           2520.24
# 6                           2379.29
# 7                           7386.65
# 8                          22723.10
# 9                          11377.76

# %%
target = df["#_of_deaths"]
target_names = ["negative", "positive"]

# %%
data = df.drop("Region", axis=1)
feature_names = data.columns
data.head()
# Out:
#      Year  #_of_deaths  Lifetime risk (%)  deaths per 100k live births  \
# 0  1997.0        470.0           0.020779                         11.0
# 1  1998.0        470.0           0.020667                         11.0
# 2  1996.0        480.0           0.021541                         11.0
# 3  1992.0        490.0           0.022674                         11.0
# 4  1999.0        490.0           0.021502                         11.0
#
#    GDP per capita
# 0     40981.44392
# 1     42302.94407
# 2     39697.16222
# 3     36600.74711
# 4     43809.16368

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')

# %%
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train, y_train)
# Out:
# C:\Users\leite\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-7bc77dee2636> in <module>
#       1 # Fit the model using the grid search estimator.
#       2 # This will take the SVC model and try each combination of parameters
# ----> 3 grid.fit(X_train, y_train)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     603         """
#     604         estimator = self.estimator
# --> 605         cv = check_cv(self.cv, y, classifier=is_classifier(estimator))
#     606
#     607         scorers, self.multimetric_ = _check_multimetric_scoring(
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py in check_cv(cv, y, classifier)
#    1981     if isinstance(cv, numbers.Integral):
#    1982         if (classifier and (y is not None) and
# -> 1983                 (type_of_target(y) in ('binary', 'multiclass'))):
#    1984             return StratifiedKFold(cv)
#    1985         else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     282     if y.dtype.kind == 'f' and np.any(y != y.astype(int)):
#     283         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 284         _assert_all_finite(y)
#     285         return 'continuous' + suffix
#     286
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# List the best parameters for this dataset
print(grid.best_params_)

# %%
# List the best score
print(grid.best_score_)

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=["blue", "red"]))
